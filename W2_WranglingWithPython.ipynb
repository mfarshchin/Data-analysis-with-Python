# %% [markdown]
# # IBM Coursera: Data Wrangling with Python, Week 2

# %% [markdown]
# ## 1- PRE-PROCESSING DATA IN PYTHON

# %%
# read csv file and import the data frame
import pandas as pd
import numpy as np
DF=pd.read_csv('CarsDF.csv')
DF.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type spiration  \
# 0           0          3                 ?  alfa-romero       gas       std
# 1           1          3                 ?  alfa-romero       gas       std
# 2           2          1                 ?  alfa-romero       gas       std
# 3           3          2               164         audi       gas       std
# 4           4          2               164         audi       gas       std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %%
# simple data frame operations
# assign the data frame to a new variable: we should use pandas copy with deep=True
D1=DF.copy(deep=True)
D1['symboling']=D1['symboling']+1
D1.head()
DF.head()# note that the original data frame remains unchanged
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type spiration  \
# 0           0          3                 ?  alfa-romero       gas       std
# 1           1          3                 ?  alfa-romero       gas       std
# 2           2          1                 ?  alfa-romero       gas       std
# 3           3          2               164         audi       gas       std
# 4           4          2               164         audi       gas       std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %%
# remove a row of data frame (drop)
D1=DF.copy(deep=True)
# remove first row
D1.drop([0,1,3], inplace = True)
D1.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type spiration  \
# 2           2          1                 ?  alfa-romero       gas       std
# 4           4          2               164         audi       gas       std
# 5           5          2                 ?         audi       gas       std
# 6           6          1               158         audi       gas       std
# 7           7          1                 ?         audi       gas       std
#
#   num-of-doors body-style drive-wheels engine-location  ...  engine-size  \
# 2          two  hatchback          rwd           front  ...          152
# 4         four      sedan          4wd           front  ...          136
# 5          two      sedan          fwd           front  ...          136
# 6         four      sedan          fwd           front  ...          136
# 7         four      wagon          fwd           front  ...          136
#
# ...

# %%
# delete a column of data in a data frame
D1=DF.copy(deep=True)
# remove 'symboling' column
D1.drop(['symboling'], axis=1, inplace = True)
D1.head()
# Out:
#    Unnamed: 0 normalized-losses         make fuel-type spiration num-of-doors  \
# 0           0                 ?  alfa-romero       gas       std          two
# 1           1                 ?  alfa-romero       gas       std          two
# 2           2                 ?  alfa-romero       gas       std          two
# 3           3               164         audi       gas       std         four
# 4           4               164         audi       gas       std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ## 2- DEALING WITH MISSING VALUES IN PYTHON

# %% [markdown]
# - Delete the missing value
# - Replace the missing value
# - Leave it as missing value

# %%
# to drop the ? values from the data frame rows, corresponing to the "normalized-losses" column
# we perform the following
D1=DF.copy(deep=True)
# replace the ? with NaN
D1 = D1.replace('?', np.NaN)
# use dropna function
D1=D1.dropna()
D1.head()
# Out:
#     Unnamed: 0  symboling normalized-losses  make fuel-type spiration  \
# 3            3          2               164  audi       gas       std
# 4            4          2               164  audi       gas       std
# 6            6          1               158  audi       gas       std
# 8            8          1               158  audi       gas     turbo
# 10          10          2               192   bmw       gas       std
#
#    num-of-doors body-style drive-wheels engine-location  ...  engine-size  \
# 3          four      sedan          fwd           front  ...          109
# 4          four      sedan          4wd           front  ...          136
# 6          four      sedan          fwd           front  ...          136
# 8          four      sedan          fwd           front  ...          131
# 10          two      sedan          rwd           front  ...          108
#
#     fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  \
# ...

# %%
# evaluating for missing data
D1=DF.copy(deep=True)
D1.replace("?", np.nan, inplace = True)
missing_data=D1.isnull()
missing_data.head(5)
# Out:
#    Unnamed: 0  symboling  normalized-losses   make  fuel-type  spiration  \
# 0       False      False               True  False      False      False
# 1       False      False               True  False      False      False
# 2       False      False               True  False      False      False
# 3       False      False              False  False      False      False
# 4       False      False              False  False      False      False
#
#    num-of-doors  body-style  drive-wheels  engine-location  ...  engine-size  \
# 0         False       False         False            False  ...        False
# 1         False       False         False            False  ...        False
# 2         False       False         False            False  ...        False
# 3         False       False         False            False  ...        False
# 4         False       False         False            False  ...        False
#
# ...

# %%
# count missing data in each column
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Unnamed: 0
# False    205
# Name: Unnamed: 0, dtype: int64
#
# symboling
# False    205
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# spiration
# False    205
# Name: spiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width:
# False    205
# Name: width:, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# ...

# %% [markdown]
# ## 3- DATA FORMATING IN PYTHON

# %%
# convert city-mpg to city-L/100km
D1=DF.copy(deep=True)
D1['city-mpg']=235/D1['city-mpg']
D1.rename(columns={'city-mpg':'city-L/100km'},inplace=True)

# %%
D1['city-L/100km']
# Out:
# 0      11.190476
# 1      11.190476
# 2      12.368421
# 3       9.791667
# 4      13.055556
#          ...
# 200    10.217391
# 201    12.368421
# 202    13.055556
# 203     9.038462
# 204    12.368421
# Name: city-mpg, Length: 205, dtype: float64

# %%
# identify the data types of a dataframe
D1.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# spiration             object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width:               float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-L/100km         float64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# convert the data type
D1[["price"]] = D1[["price"]].astype("float")
D1['price'].dtypes
# Out:
# dtype('float64')

# %%
# convert the data type to calculate mean
D1=DF.copy(deep=True)
D1.replace('?',np.nan,inplace=True)
avg_norm_loss = D1["normalized-losses"].astype("float").mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %%
# see which values are present in a column
D1['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %% [markdown]
# ## 3- DATA FORMATTING IN PYTHON

# %% [markdown]
# apply z-score scaling to the length column: $\frac{x-\mu_x}{\sigma_x}$

# %%
D1['length']=(D1['length']-D1['length'].mean())/D1['length'].std()
D1['length']
# Out:
# 3      0.363282
# 4      0.363282
# 6      1.760466
# 8      1.760466
# 10     0.380638
#          ...
# 200    1.422018
# 201    1.422018
# 202    1.422018
# 203    1.422018
# 204    1.422018
# Name: length, Length: 159, dtype: float64

# %%
# convert data format
# first drop all rows with nan
D1.dropna(axis=0, inplace=True)
# Then reset index, because we droped rows
D1.reset_index(drop=True, inplace=True)
# now convert data format
df=D1
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")
D1.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# spiration             object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width:               float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# ## 4- BINNING IN PYTHON

# %% [markdown]
# ## 3- DATA FORMATTING IN PYTHON

# %%
# categorize the prices into groups (bins)
bins=np.linspace(min(D1['price']),max(D1['price']),4)
bins
# Out:
# array([ 5118.        , 15097.33333333, 25076.66666667, 35056.        ])

# %%
group_names=['low','medium','high']

# %%
D1['price-binned']=pd.cut(D1['price'],bins,labels=group_names,include_lowest=True)

# %%
D1[['price','price-binned']].head()
# Out:
#       price price-binned
# 3   13950.0          low
# 4   17450.0       medium
# 6   17710.0       medium
# 8   23875.0       medium
# 10  16430.0       medium

# %% [markdown]
# ## 5- CONVERT CATEGORICAL VARIABLES INTO QUANTITATIVE VARIABLES

# %%
pd.get_dummies(D1['fuel-type']) # this is called on-hot encoding
# Out:
#      diesel  gas
# 3         0    1
# 4         0    1
# 6         0    1
# 8         0    1
# 10        0    1
# ..      ...  ...
# 200       0    1
# 201       0    1
# 202       0    1
# 203       1    0
# 204       0    1
#
# [159 rows x 2 columns]

# %%
D1=DF.copy(deep=True)
D1.replace('?',np.nan, inplace=True)
D1.dropna(axis=0, inplace=True)
D1["horsepower"]=D1["horsepower"].astype(int, copy=True)
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')
